# %% [markdown]
# <a href="https://colab.research.google.com/github/SSnehitha004/Deep_Learning_Projects/blob/main/Instance_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.utils import load_img, array_to_img, img_to_array
from tensorflow.keras.optimizers import Adam
import random
import os
from tqdm.notebook import tqdm

# %matplotlib inline

from colorama import Style, Fore
blk = Style.BRIGHT + Fore.BLACK
red = Style.BRIGHT + Fore.RED
blu = Style.BRIGHT + Fore.BLUE
res = Style.RESET_ALL

# %% [markdown]
# Data Prepration

# %%
BASE_DIR= '/content/drive/MyDrive/input/segmentation_full_body_mads_dataset_1192_img'
img_path= os.listdir(BASE_DIR+'images')
mask_path= os.listdir(BASE_DIR+'masks')

# %%
img_size = 256

# %%
X_train, X_test, y_train, y_test = train_test_split(img_path, mask_path, test_size=0.2, random_state=22)

# %%
def load_img(path):
    img= cv2.imread(path)
    img= cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

# %%
def load_data(path_list, gray=False):
    data=[]
    for path in tqdm(path_list):
        img= load_img(path)
        if gray:
            img= img[:, :, 0:1]
        img= cv2.resize(img, (img_size, img_size))
        data.append(img)
    return np.array(data)

# %%
X_train= load_data([BASE_DIR + 'images/' + x for x in X_train])/255.0
X_test= load_data([BASE_DIR + 'images/' + x for x in X_test])/255.0
# Out:
#   0%|          | 0/953 [00:00<?, ?it/s]
#   0%|          | 0/239 [00:00<?, ?it/s]

# %%
Y_train= load_data([BASE_DIR + 'masks/' + x for x in y_train], gray=True)/255.0
Y_test= load_data([BASE_DIR + 'masks/' + x for x in y_test], gray=True)/255.0
Y_train= Y_train.reshape(-1, img_size, img_size, 1)
Y_test= Y_test.reshape(-1, img_size, img_size, 1)
# Out:
#   0%|          | 0/953 [00:00<?, ?it/s]
#   0%|          | 0/239 [00:00<?, ?it/s]

# %%
print(f"===( Train )===")
print(f"Images shape : {X_train.shape}")
print(f"Masks shape : {Y_train.shape}")

print(f"===( Test )===")
print(f"Images shape : {X_test.shape}")
print(f"Masks shape : {Y_test.shape}")
# Out:
# ===( Train )===
# Images shape : (953, 256, 256, 3)
# Masks shape : (953, 256, 256, 1)
# ===( Test )===
# Images shape : (239, 256, 256, 3)
# Masks shape : (239, 256, 256, 1)

# %%
def conv_block(shape, out_ch, rate=1):
    x = tf.keras.layers.Conv2D(out_ch, 3, padding="same", dilation_rate=1)(shape)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x

def RSU_L(shape, out_ch, M_ch, num_layers, rate=2):
    x = conv_block(shape, out_ch)
    inp_ch = x

    skip_features = []
    x = conv_block(x, M_ch)
    skip_features.append(x)

    for i in range(num_layers-2):
        x = tf.keras.layers.MaxPool2D((2, 2))(x)
        x = conv_block(x, M_ch)
        skip_features.append(x)

    x = conv_block(x, M_ch, rate=rate)
    skip_features.reverse()
    x = tf.keras.layers.Concatenate()([x, skip_features[0]])
    x = conv_block(x, M_ch)

    for i in range(num_layers-3):
        x = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(x)
        x = tf.keras.layers.Concatenate()([x, skip_features[i+1]])
        x = conv_block(x, M_ch)

    x = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(x)
    x = tf.keras.layers.Concatenate()([x, skip_features[-1]])
    x = conv_block(x, out_ch)

    x = tf.keras.layers.Add()([x, inp_ch])
    return x

def RSU_4F(shape, out_ch, M_ch):
    x0 = conv_block(shape, out_ch, rate=1)

    x1 = conv_block(x0, M_ch, rate=1)
    x2 = conv_block(x1, M_ch, rate=2)
    x3 = conv_block(x2, M_ch, rate=4)

    x4 = conv_block(x3, M_ch, rate=8)

    x = tf.keras.layers.Concatenate()([x4, x3])
    x = conv_block(x, M_ch, rate=4)

    x = tf.keras.layers.Concatenate()([x, x2])
    x = conv_block(x, M_ch, rate=2)

    x = tf.keras.layers.Concatenate()([x, x1])
    x = conv_block(x, out_ch, rate=1)

    x = tf.keras.layers.Add()([x, x0])
    return x

def u2net(shape, out_ch, M_ch, num_classes=1):
    inputs = tf.keras.layers.Input(shape)

    e1 = RSU_L(inputs, out_ch[0], M_ch[0], 7)
    p1 = tf.keras.layers.MaxPool2D((2, 2))(e1)

    e2 = RSU_L(p1, out_ch[1], M_ch[1], 6)
    p2 = tf.keras.layers.MaxPool2D((2, 2))(e2)

    e3 = RSU_L(p2, out_ch[2], M_ch[2], 5)
    p3 = tf.keras.layers.MaxPool2D((2, 2))(e3)

    e4 = RSU_L(p3, out_ch[3], M_ch[3], 4)
    p4 = tf.keras.layers.MaxPool2D((2, 2))(e4)

    e5 = RSU_4F(p4, out_ch[4], M_ch[4])
    p5 = tf.keras.layers.MaxPool2D((2, 2))(e5)

    b1 = RSU_4F(p5, out_ch[5], M_ch[5])
    b2 = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(b1)

    d1 = tf.keras.layers.Concatenate()([b2, e5])
    d1 = RSU_4F(d1, out_ch[6], M_ch[6])
    u1 = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(d1)

    d2 = tf.keras.layers.Concatenate()([u1, e4])
    d2 = RSU_L(d2, out_ch[7], M_ch[7], 4)
    u2 = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(d2)

    d3 = tf.keras.layers.Concatenate()([u2, e3])
    d3 = RSU_L(d3, out_ch[8], M_ch[8], 5)
    u3 = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(d3)

    d4 = tf.keras.layers.Concatenate()([u3, e2])
    d4 = RSU_L(d4, out_ch[9], M_ch[9], 6)
    u4 = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(d4)

    d5 = tf.keras.layers.Concatenate()([u4, e1])
    d5 = RSU_L(d5, out_ch[10], M_ch[10], 7)


    y1 = tf.keras.layers.Conv2D(num_classes, 3, padding="same")(d5)

    y2 = tf.keras.layers.Conv2D(num_classes, 3, padding="same")(d4)
    y2 = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(y2)

    y3 = tf.keras.layers.Conv2D(num_classes, 3, padding="same")(d3)
    y3 = tf.keras.layers.UpSampling2D(size=(4, 4), interpolation="bilinear")(y3)

    y4 = tf.keras.layers.Conv2D(num_classes, 3, padding="same")(d2)
    y4 = tf.keras.layers.UpSampling2D(size=(8, 8), interpolation="bilinear")(y4)

    y5 = tf.keras.layers.Conv2D(num_classes, 3, padding="same")(d1)
    y5 = tf.keras.layers.UpSampling2D(size=(16, 16), interpolation="bilinear")(y5)

    y6 = tf.keras.layers.Conv2D(num_classes, 3, padding="same")(b1)
    y6 = tf.keras.layers.UpSampling2D(size=(32, 32), interpolation="bilinear")(y6)

    y0 = tf.keras.layers.Concatenate()([y1, y2, y3, y4, y5, y6])
    y0 = tf.keras.layers.Conv2D(num_classes, 3, padding="same")(y0)

    y0 = tf.keras.layers.Activation("sigmoid")(y0)
    y1 = tf.keras.layers.Activation("sigmoid")(y1)
    y2 = tf.keras.layers.Activation("sigmoid")(y2)
    y3 = tf.keras.layers.Activation("sigmoid")(y3)
    y4 = tf.keras.layers.Activation("sigmoid")(y4)
    y5 = tf.keras.layers.Activation("sigmoid")(y5)
    y6 = tf.keras.layers.Activation("sigmoid")(y6)

    model = tf.keras.models.Model(inputs, outputs=y0, name="U2-Net")
    return model

def build_u2net(input_shape, num_classes=1):
    out_ch = [64, 128, 256, 512, 512, 512, 512, 256, 128, 64, 64]
    M_ch = [32, 32, 64, 128, 256, 256, 256, 128, 64, 32, 16]
    model = u2net(input_shape, out_ch, M_ch, num_classes=num_classes)
    return model

def build_u2net_lite(input_shape, num_classes=1):
    out_ch = [64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64]
    M_ch = [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]
    model = u2net(input_shape, out_ch, M_ch, num_classes=num_classes)
    return model

u2net_model = build_u2net((img_size, img_size, 3))
u2net_model.summary()
# Out:
# Model: "U2-Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 256, 256, 64)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)         18464     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 32)         128       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 32)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)         9248      ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128, 128, 32)         128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_2[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)           9248      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 32)           128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 64, 64, 32)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 32)           0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)           9248      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 32)           128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32, 32, 32)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 32)           0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 32)           9248      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 16, 16, 32)           128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 16, 16, 32)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 8, 32)             0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 32)             9248      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 8, 8, 32)             128       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 8, 8, 32)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 32)             9248      ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 8, 8, 32)             128       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 8, 8, 32)             0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 8, 8, 64)             0         ['activation_7[0][0]',
#                                                                      'activation_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 32)             18464     ['concatenate[0][0]']
#
#  batch_normalization_8 (Bat  (None, 8, 8, 32)             128       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 8, 8, 32)             0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  up_sampling2d (UpSampling2  (None, 16, 16, 32)           0         ['activation_8[0][0]']
#  D)
#
#  concatenate_1 (Concatenate  (None, 16, 16, 64)           0         ['up_sampling2d[0][0]',
#  )                                                                   'activation_5[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 32)           18464     ['concatenate_1[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 32)           128       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 32)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  up_sampling2d_1 (UpSamplin  (None, 32, 32, 32)           0         ['activation_9[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 32, 32, 64)           0         ['up_sampling2d_1[0][0]',
#  )                                                                   'activation_4[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 32)           18464     ['concatenate_2[0][0]']
#
#  batch_normalization_10 (Ba  (None, 32, 32, 32)           128       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 32)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  up_sampling2d_2 (UpSamplin  (None, 64, 64, 32)           0         ['activation_10[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 64, 64, 64)           0         ['up_sampling2d_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 32)           18464     ['concatenate_3[0][0]']
#
#  batch_normalization_11 (Ba  (None, 64, 64, 32)           128       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 64, 64, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  up_sampling2d_3 (UpSamplin  (None, 128, 128, 32)         0         ['activation_11[0][0]']
#  g2D)
#
#  concatenate_4 (Concatenate  (None, 128, 128, 64)         0         ['up_sampling2d_3[0][0]',
#  )                                                                   'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 32)         18464     ['concatenate_4[0][0]']
#
#  batch_normalization_12 (Ba  (None, 128, 128, 32)         128       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  up_sampling2d_4 (UpSamplin  (None, 256, 256, 32)         0         ['activation_12[0][0]']
#  g2D)
#
#  concatenate_5 (Concatenate  (None, 256, 256, 64)         0         ['up_sampling2d_4[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 256, 256, 64)         36928     ['concatenate_5[0][0]']
#
#  batch_normalization_13 (Ba  (None, 256, 256, 64)         256       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  add (Add)                   (None, 256, 256, 64)         0         ['activation_13[0][0]',
#                                                                      'activation[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 128, 128, 64)         0         ['add[0][0]']
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 128)        73856     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_14 (Ba  (None, 128, 128, 128)        512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 32)         36896     ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 128, 128, 32)         128       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  max_pooling2d_6 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_15[0][0]']
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 64, 64, 32)           9248      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_16 (Ba  (None, 64, 64, 32)           128       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 64, 64, 32)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 32, 32, 32)           0         ['activation_16[0][0]']
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 32)           9248      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_17 (Ba  (None, 32, 32, 32)           128       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 32, 32, 32)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 16, 16, 32)           0         ['activation_17[0][0]']
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 32)           9248      ['max_pooling2d_8[0][0]']
#
#  batch_normalization_18 (Ba  (None, 16, 16, 32)           128       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 16, 16, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  max_pooling2d_9 (MaxPoolin  (None, 8, 8, 32)             0         ['activation_18[0][0]']
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 32)             9248      ['max_pooling2d_9[0][0]']
#
#  batch_normalization_19 (Ba  (None, 8, 8, 32)             128       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 8, 8, 32)             0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 32)             9248      ['activation_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, 8, 8, 32)             128       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 8, 8, 32)             0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  concatenate_6 (Concatenate  (None, 8, 8, 64)             0         ['activation_20[0][0]',
#  )                                                                   'activation_19[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 32)             18464     ['concatenate_6[0][0]']
#
#  batch_normalization_21 (Ba  (None, 8, 8, 32)             128       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 8, 8, 32)             0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  up_sampling2d_5 (UpSamplin  (None, 16, 16, 32)           0         ['activation_21[0][0]']
#  g2D)
#
#  concatenate_7 (Concatenate  (None, 16, 16, 64)           0         ['up_sampling2d_5[0][0]',
#  )                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 32)           18464     ['concatenate_7[0][0]']
#
#  batch_normalization_22 (Ba  (None, 16, 16, 32)           128       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 16, 16, 32)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  up_sampling2d_6 (UpSamplin  (None, 32, 32, 32)           0         ['activation_22[0][0]']
#  g2D)
#
#  concatenate_8 (Concatenate  (None, 32, 32, 64)           0         ['up_sampling2d_6[0][0]',
#  )                                                                   'activation_17[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 32, 32, 32)           18464     ['concatenate_8[0][0]']
#
#  batch_normalization_23 (Ba  (None, 32, 32, 32)           128       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 32, 32, 32)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  up_sampling2d_7 (UpSamplin  (None, 64, 64, 32)           0         ['activation_23[0][0]']
#  g2D)
#
#  concatenate_9 (Concatenate  (None, 64, 64, 64)           0         ['up_sampling2d_7[0][0]',
#  )                                                                   'activation_16[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 32)           18464     ['concatenate_9[0][0]']
#
#  batch_normalization_24 (Ba  (None, 64, 64, 32)           128       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 64, 64, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  up_sampling2d_8 (UpSamplin  (None, 128, 128, 32)         0         ['activation_24[0][0]']
#  g2D)
#
#  concatenate_10 (Concatenat  (None, 128, 128, 64)         0         ['up_sampling2d_8[0][0]',
#  e)                                                                  'activation_15[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 128)        73856     ['concatenate_10[0][0]']
#
#  batch_normalization_25 (Ba  (None, 128, 128, 128)        512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  add_1 (Add)                 (None, 128, 128, 128)        0         ['activation_25[0][0]',
#                                                                      'activation_14[0][0]']
#
#  max_pooling2d_10 (MaxPooli  (None, 64, 64, 128)          0         ['add_1[0][0]']
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 256)          295168    ['max_pooling2d_10[0][0]']
#
#  batch_normalization_26 (Ba  (None, 64, 64, 256)          1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 64)           147520    ['activation_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 64, 64, 64)           256       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  max_pooling2d_11 (MaxPooli  (None, 32, 32, 64)           0         ['activation_27[0][0]']
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 64)           36928     ['max_pooling2d_11[0][0]']
#
#  batch_normalization_28 (Ba  (None, 32, 32, 64)           256       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 32, 32, 64)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  max_pooling2d_12 (MaxPooli  (None, 16, 16, 64)           0         ['activation_28[0][0]']
#  ng2D)
#
#  conv2d_29 (Conv2D)          (None, 16, 16, 64)           36928     ['max_pooling2d_12[0][0]']
#
#  batch_normalization_29 (Ba  (None, 16, 16, 64)           256       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 16, 16, 64)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_13 (MaxPooli  (None, 8, 8, 64)             0         ['activation_29[0][0]']
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, 8, 8, 64)             36928     ['max_pooling2d_13[0][0]']
#
#  batch_normalization_30 (Ba  (None, 8, 8, 64)             256       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 8, 8, 64)             256       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  concatenate_11 (Concatenat  (None, 8, 8, 128)            0         ['activation_31[0][0]',
#  e)                                                                  'activation_30[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 8, 8, 64)             73792     ['concatenate_11[0][0]']
#
#  batch_normalization_32 (Ba  (None, 8, 8, 64)             256       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  up_sampling2d_9 (UpSamplin  (None, 16, 16, 64)           0         ['activation_32[0][0]']
#  g2D)
#
#  concatenate_12 (Concatenat  (None, 16, 16, 128)          0         ['up_sampling2d_9[0][0]',
#  e)                                                                  'activation_29[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 64)           73792     ['concatenate_12[0][0]']
#
#  batch_normalization_33 (Ba  (None, 16, 16, 64)           256       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 16, 16, 64)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  up_sampling2d_10 (UpSampli  (None, 32, 32, 64)           0         ['activation_33[0][0]']
#  ng2D)
#
#  concatenate_13 (Concatenat  (None, 32, 32, 128)          0         ['up_sampling2d_10[0][0]',
#  e)                                                                  'activation_28[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 32, 32, 64)           73792     ['concatenate_13[0][0]']
#
#  batch_normalization_34 (Ba  (None, 32, 32, 64)           256       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 32, 32, 64)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  up_sampling2d_11 (UpSampli  (None, 64, 64, 64)           0         ['activation_34[0][0]']
#  ng2D)
#
#  concatenate_14 (Concatenat  (None, 64, 64, 128)          0         ['up_sampling2d_11[0][0]',
#  e)                                                                  'activation_27[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 64, 64, 256)          295168    ['concatenate_14[0][0]']
#
#  batch_normalization_35 (Ba  (None, 64, 64, 256)          1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 64, 64, 256)          0         ['activation_35[0][0]',
#                                                                      'activation_26[0][0]']
#
#  max_pooling2d_14 (MaxPooli  (None, 32, 32, 256)          0         ['add_2[0][0]']
#  ng2D)
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 512)          1180160   ['max_pooling2d_14[0][0]']
#
#  batch_normalization_36 (Ba  (None, 32, 32, 512)          2048      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 128)          589952    ['activation_36[0][0]']
#
#  batch_normalization_37 (Ba  (None, 32, 32, 128)          512       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  max_pooling2d_15 (MaxPooli  (None, 16, 16, 128)          0         ['activation_37[0][0]']
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 128)          147584    ['max_pooling2d_15[0][0]']
#
#  batch_normalization_38 (Ba  (None, 16, 16, 128)          512       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 16, 16, 128)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  max_pooling2d_16 (MaxPooli  (None, 8, 8, 128)            0         ['activation_38[0][0]']
#  ng2D)
#
#  conv2d_39 (Conv2D)          (None, 8, 8, 128)            147584    ['max_pooling2d_16[0][0]']
#
#  batch_normalization_39 (Ba  (None, 8, 8, 128)            512       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_39[0][0]']
#
#  batch_normalization_40 (Ba  (None, 8, 8, 128)            512       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  concatenate_15 (Concatenat  (None, 8, 8, 256)            0         ['activation_40[0][0]',
#  e)                                                                  'activation_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 8, 8, 128)            295040    ['concatenate_15[0][0]']
#
#  batch_normalization_41 (Ba  (None, 8, 8, 128)            512       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_41[0][0]
#                                                                     ']
#
# ...
#  atchNormalization)
#
#  activation_102 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  max_pooling2d_31 (MaxPooli  (None, 16, 16, 16)           0         ['activation_102[0][0]']
#  ng2D)
#
#  conv2d_103 (Conv2D)         (None, 16, 16, 16)           2320      ['max_pooling2d_31[0][0]']
#
#  batch_normalization_103 (B  (None, 16, 16, 16)           64        ['conv2d_103[0][0]']
#  atchNormalization)
#
#  activation_103 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  max_pooling2d_32 (MaxPooli  (None, 8, 8, 16)             0         ['activation_103[0][0]']
#  ng2D)
#
#  conv2d_104 (Conv2D)         (None, 8, 8, 16)             2320      ['max_pooling2d_32[0][0]']
#
#  batch_normalization_104 (B  (None, 8, 8, 16)             64        ['conv2d_104[0][0]']
#  atchNormalization)
#
#  activation_104 (Activation  (None, 8, 8, 16)             0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  conv2d_105 (Conv2D)         (None, 8, 8, 16)             2320      ['activation_104[0][0]']
#
#  batch_normalization_105 (B  (None, 8, 8, 16)             64        ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_105 (Activation  (None, 8, 8, 16)             0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  concatenate_44 (Concatenat  (None, 8, 8, 32)             0         ['activation_105[0][0]',
#  e)                                                                  'activation_104[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 8, 8, 16)             4624      ['concatenate_44[0][0]']
#
#  batch_normalization_106 (B  (None, 8, 8, 16)             64        ['conv2d_106[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 8, 8, 16)             0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  up_sampling2d_28 (UpSampli  (None, 16, 16, 16)           0         ['activation_106[0][0]']
#  ng2D)
#
#  concatenate_45 (Concatenat  (None, 16, 16, 32)           0         ['up_sampling2d_28[0][0]',
#  e)                                                                  'activation_103[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 16, 16, 16)           4624      ['concatenate_45[0][0]']
#
#  batch_normalization_107 (B  (None, 16, 16, 16)           64        ['conv2d_107[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  up_sampling2d_29 (UpSampli  (None, 32, 32, 16)           0         ['activation_107[0][0]']
#  ng2D)
#
#  concatenate_46 (Concatenat  (None, 32, 32, 32)           0         ['up_sampling2d_29[0][0]',
#  e)                                                                  'activation_102[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 32, 32, 16)           4624      ['concatenate_46[0][0]']
#
#  batch_normalization_108 (B  (None, 32, 32, 16)           64        ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_108 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  up_sampling2d_30 (UpSampli  (None, 64, 64, 16)           0         ['activation_108[0][0]']
#  ng2D)
#
#  concatenate_47 (Concatenat  (None, 64, 64, 32)           0         ['up_sampling2d_30[0][0]',
#  e)                                                                  'activation_101[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 64, 64, 16)           4624      ['concatenate_47[0][0]']
#
#  batch_normalization_109 (B  (None, 64, 64, 16)           64        ['conv2d_109[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 64, 64, 16)           0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  up_sampling2d_31 (UpSampli  (None, 128, 128, 16)         0         ['activation_109[0][0]']
#  ng2D)
#
#  concatenate_48 (Concatenat  (None, 128, 128, 32)         0         ['up_sampling2d_31[0][0]',
#  e)                                                                  'activation_100[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 128, 128, 16)         4624      ['concatenate_48[0][0]']
#
#  batch_normalization_110 (B  (None, 128, 128, 16)         64        ['conv2d_110[0][0]']
#  atchNormalization)
#
#  activation_110 (Activation  (None, 128, 128, 16)         0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  up_sampling2d_32 (UpSampli  (None, 256, 256, 16)         0         ['activation_110[0][0]']
#  ng2D)
#
#  concatenate_49 (Concatenat  (None, 256, 256, 32)         0         ['up_sampling2d_32[0][0]',
#  e)                                                                  'activation_99[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 256, 256, 64)         18496     ['concatenate_49[0][0]']
#
#  batch_normalization_111 (B  (None, 256, 256, 64)         256       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  activation_111 (Activation  (None, 256, 256, 64)         0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  add_10 (Add)                (None, 256, 256, 64)         0         ['activation_111[0][0]',
#                                                                      'activation_98[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 128, 128, 1)          577       ['add_9[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 64, 64, 1)            1153      ['add_8[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 32, 32, 1)            2305      ['add_7[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 16, 16, 1)            4609      ['add_6[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 8, 8, 1)              4609      ['add_5[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 256, 256, 1)          577       ['add_10[0][0]']
#
#  up_sampling2d_33 (UpSampli  (None, 256, 256, 1)          0         ['conv2d_113[0][0]']
#  ng2D)
#
#  up_sampling2d_34 (UpSampli  (None, 256, 256, 1)          0         ['conv2d_114[0][0]']
#  ng2D)
#
#  up_sampling2d_35 (UpSampli  (None, 256, 256, 1)          0         ['conv2d_115[0][0]']
#  ng2D)
#
#  up_sampling2d_36 (UpSampli  (None, 256, 256, 1)          0         ['conv2d_116[0][0]']
#  ng2D)
#
#  up_sampling2d_37 (UpSampli  (None, 256, 256, 1)          0         ['conv2d_117[0][0]']
#  ng2D)
#
#  concatenate_50 (Concatenat  (None, 256, 256, 6)          0         ['conv2d_112[0][0]',
#  e)                                                                  'up_sampling2d_33[0][0]',
#                                                                      'up_sampling2d_34[0][0]',
#                                                                      'up_sampling2d_35[0][0]',
#                                                                      'up_sampling2d_36[0][0]',
#                                                                      'up_sampling2d_37[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 256, 256, 1)          55        ['concatenate_50[0][0]']
#
#  activation_112 (Activation  (None, 256, 256, 1)          0         ['conv2d_118[0][0]']
#  )
#
# ==================================================================================================
# Total params: 44038717 (167.99 MB)
# Trainable params: 44009917 (167.88 MB)
# Non-trainable params: 28800 (112.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Model Training

# %%
opt = Adam(learning_rate=1e-3)
u2net_model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
def get_callbacks():
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)
    checkpoint = ModelCheckpoint('full_body.hdf5',verbose=1, save_best_only= True)
    early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
    return [reduce_lr, checkpoint, early_stop]

# %%
hsitory = u2net_model.fit(X_train, Y_train, validation_split = 0.2, batch_size = 16, epochs = 30, callbacks=get_callbacks())
# Out:
# Epoch 1/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1586 - accuracy: 0.9613
# Epoch 1: val_loss improved from inf to 18785.47461, saving model to full_body.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 48/48 [==============================] - 225s 2s/step - loss: 0.1586 - accuracy: 0.9613 - val_loss: 18785.4746 - val_accuracy: 0.0484 - lr: 0.0010
# Epoch 2/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9778
# Epoch 2: val_loss improved from 18785.47461 to 3.41962, saving model to full_body.hdf5
# 48/48 [==============================] - 53s 1s/step - loss: 0.0204 - accuracy: 0.9778 - val_loss: 3.4196 - val_accuracy: 0.6638 - lr: 0.0010
# Epoch 3/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9794
# Epoch 3: val_loss improved from 3.41962 to 0.77764, saving model to full_body.hdf5
# 48/48 [==============================] - 55s 1s/step - loss: 0.0148 - accuracy: 0.9794 - val_loss: 0.7776 - val_accuracy: 0.9441 - lr: 0.0010
# Epoch 4/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9799
# Epoch 4: val_loss did not improve from 0.77764
# 48/48 [==============================] - 48s 999ms/step - loss: 0.0128 - accuracy: 0.9799 - val_loss: 0.8891 - val_accuracy: 0.9441 - lr: 0.0010
# Epoch 5/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9802
# Epoch 5: val_loss did not improve from 0.77764
# 48/48 [==============================] - 49s 1s/step - loss: 0.0113 - accuracy: 0.9802 - val_loss: 0.8618 - val_accuracy: 0.9441 - lr: 0.0010
# Epoch 6/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9803
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 6: val_loss did not improve from 0.77764
# 48/48 [==============================] - 50s 1s/step - loss: 0.0106 - accuracy: 0.9803 - val_loss: 0.8314 - val_accuracy: 0.9441 - lr: 0.0010
# Epoch 7/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9805
# Epoch 7: val_loss improved from 0.77764 to 0.63040, saving model to full_body.hdf5
# 48/48 [==============================] - 54s 1s/step - loss: 0.0097 - accuracy: 0.9805 - val_loss: 0.6304 - val_accuracy: 0.9446 - lr: 1.0000e-04
# Epoch 8/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9805
# Epoch 8: val_loss improved from 0.63040 to 0.32899, saving model to full_body.hdf5
# 48/48 [==============================] - 65s 1s/step - loss: 0.0094 - accuracy: 0.9805 - val_loss: 0.3290 - val_accuracy: 0.9480 - lr: 1.0000e-04
# Epoch 9/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9806
# Epoch 9: val_loss improved from 0.32899 to 0.13536, saving model to full_body.hdf5
# 48/48 [==============================] - 60s 1s/step - loss: 0.0093 - accuracy: 0.9806 - val_loss: 0.1354 - val_accuracy: 0.9563 - lr: 1.0000e-04
# Epoch 10/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9806
# Epoch 10: val_loss improved from 0.13536 to 0.06048, saving model to full_body.hdf5
# 48/48 [==============================] - 59s 1s/step - loss: 0.0092 - accuracy: 0.9806 - val_loss: 0.0605 - val_accuracy: 0.9647 - lr: 1.0000e-04
# Epoch 11/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9806
# Epoch 11: val_loss improved from 0.06048 to 0.03190, saving model to full_body.hdf5
# 48/48 [==============================] - 62s 1s/step - loss: 0.0091 - accuracy: 0.9806 - val_loss: 0.0319 - val_accuracy: 0.9704 - lr: 1.0000e-04
# Epoch 12/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9806
# Epoch 12: val_loss improved from 0.03190 to 0.01960, saving model to full_body.hdf5
# 48/48 [==============================] - 71s 1s/step - loss: 0.0091 - accuracy: 0.9806 - val_loss: 0.0196 - val_accuracy: 0.9735 - lr: 1.0000e-04
# Epoch 13/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9806
# Epoch 13: val_loss improved from 0.01960 to 0.01441, saving model to full_body.hdf5
# 48/48 [==============================] - 74s 2s/step - loss: 0.0090 - accuracy: 0.9806 - val_loss: 0.0144 - val_accuracy: 0.9747 - lr: 1.0000e-04
# Epoch 14/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9806
# Epoch 14: val_loss improved from 0.01441 to 0.01216, saving model to full_body.hdf5
# 48/48 [==============================] - 72s 2s/step - loss: 0.0089 - accuracy: 0.9806 - val_loss: 0.0122 - val_accuracy: 0.9753 - lr: 1.0000e-04
# Epoch 15/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9806
# Epoch 15: val_loss improved from 0.01216 to 0.01136, saving model to full_body.hdf5
# 48/48 [==============================] - 64s 1s/step - loss: 0.0089 - accuracy: 0.9806 - val_loss: 0.0114 - val_accuracy: 0.9755 - lr: 1.0000e-04
# Epoch 16/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9806
# Epoch 16: val_loss improved from 0.01136 to 0.01093, saving model to full_body.hdf5
# 48/48 [==============================] - 66s 1s/step - loss: 0.0088 - accuracy: 0.9806 - val_loss: 0.0109 - val_accuracy: 0.9755 - lr: 1.0000e-04
# Epoch 17/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9806
# Epoch 17: val_loss improved from 0.01093 to 0.01073, saving model to full_body.hdf5
# 48/48 [==============================] - 65s 1s/step - loss: 0.0087 - accuracy: 0.9806 - val_loss: 0.0107 - val_accuracy: 0.9756 - lr: 1.0000e-04
# Epoch 18/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9807
# Epoch 18: val_loss improved from 0.01073 to 0.01058, saving model to full_body.hdf5
# 48/48 [==============================] - 66s 1s/step - loss: 0.0087 - accuracy: 0.9807 - val_loss: 0.0106 - val_accuracy: 0.9756 - lr: 1.0000e-04
# Epoch 19/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9807
# Epoch 19: val_loss improved from 0.01058 to 0.01053, saving model to full_body.hdf5
# 48/48 [==============================] - 61s 1s/step - loss: 0.0086 - accuracy: 0.9807 - val_loss: 0.0105 - val_accuracy: 0.9756 - lr: 1.0000e-04
# Epoch 20/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9807
# Epoch 20: val_loss did not improve from 0.01053
# 48/48 [==============================] - 48s 999ms/step - loss: 0.0086 - accuracy: 0.9807 - val_loss: 0.0105 - val_accuracy: 0.9756 - lr: 1.0000e-04
# Epoch 21/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9807
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 21: val_loss improved from 0.01053 to 0.01051, saving model to full_body.hdf5
# 48/48 [==============================] - 71s 1s/step - loss: 0.0085 - accuracy: 0.9807 - val_loss: 0.0105 - val_accuracy: 0.9756 - lr: 1.0000e-04
# Epoch 22/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9807
# Epoch 22: val_loss improved from 0.01051 to 0.01046, saving model to full_body.hdf5
# 48/48 [==============================] - 70s 1s/step - loss: 0.0084 - accuracy: 0.9807 - val_loss: 0.0105 - val_accuracy: 0.9756 - lr: 1.0000e-05
# Epoch 23/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9807
# Epoch 23: val_loss improved from 0.01046 to 0.01044, saving model to full_body.hdf5
# 48/48 [==============================] - 60s 1s/step - loss: 0.0084 - accuracy: 0.9807 - val_loss: 0.0104 - val_accuracy: 0.9756 - lr: 1.0000e-05
# Epoch 24/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9807
# Epoch 24: val_loss improved from 0.01044 to 0.01044, saving model to full_body.hdf5
# 48/48 [==============================] - 69s 1s/step - loss: 0.0084 - accuracy: 0.9807 - val_loss: 0.0104 - val_accuracy: 0.9756 - lr: 1.0000e-05
# Epoch 25/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9807
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 25: val_loss improved from 0.01044 to 0.01044, saving model to full_body.hdf5
# 48/48 [==============================] - 68s 1s/step - loss: 0.0084 - accuracy: 0.9807 - val_loss: 0.0104 - val_accuracy: 0.9756 - lr: 1.0000e-05
# Epoch 26/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9807
# Epoch 26: val_loss improved from 0.01044 to 0.01044, saving model to full_body.hdf5
# 48/48 [==============================] - 68s 1s/step - loss: 0.0083 - accuracy: 0.9807 - val_loss: 0.0104 - val_accuracy: 0.9756 - lr: 1.0000e-06
# Epoch 27/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9807
# Epoch 27: val_loss did not improve from 0.01044
# 48/48 [==============================] - 48s 1s/step - loss: 0.0083 - accuracy: 0.9807 - val_loss: 0.0104 - val_accuracy: 0.9756 - lr: 1.0000e-06
# Epoch 28/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9807
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 28: val_loss did not improve from 0.01044
# 48/48 [==============================] - 48s 995ms/step - loss: 0.0083 - accuracy: 0.9807 - val_loss: 0.0104 - val_accuracy: 0.9756 - lr: 1.0000e-06
# Epoch 29/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9807
# Epoch 29: val_loss did not improve from 0.01044
# 48/48 [==============================] - 50s 1s/step - loss: 0.0084 - accuracy: 0.9807 - val_loss: 0.0104 - val_accuracy: 0.9756 - lr: 1.0000e-07
# Epoch 30/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9807
# Epoch 30: val_loss did not improve from 0.01044
# 48/48 [==============================] - 49s 1s/step - loss: 0.0083 - accuracy: 0.9807 - val_loss: 0.0104 - val_accuracy: 0.9756 - lr: 1.0000e-07

# %% [markdown]
# Model testing

# %%
u2net_model.load_weights("full_body.hdf5")

# %%
predict = u2net_model.predict(X_test)
# Out:
# 8/8 [==============================] - 32s 485ms/step

# %%
def show_result(og, pred, target):
    fig, axs = plt.subplots(1, 3, figsize=(10,5))
    axs[0].set_title("Original")
    axs[0].imshow(og)
    axs[0].axis('off')

    axs[1].set_title("Predict")
    axs[1].imshow(pred)
    axs[1].axis('off')

    axs[2].set_title("Target")
    axs[2].imshow(target)
    axs[2].axis('off')

    plt.show()

# %%
show_test_idx = random.sample(range(239), 5)

# %%
for idx in show_test_idx:
    show_result(X_test[idx], predict[idx], Y_test[idx])

# %% [markdown]
# Evaluation

# %%
loss, accuracy = u2net_model.evaluate(X_test, Y_test)
# Out:
# 8/8 [==============================] - 4s 513ms/step - loss: 0.0107 - accuracy: 0.9770

# %%
print(f"Test Loss : {loss}")
print(f"Test Accuracy : {accuracy}")
# Out:
# Test Loss : 0.010710467584431171
# Test Accuracy : 0.976986825466156
